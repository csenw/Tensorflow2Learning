# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0-dev20200315

# %%
# Implementation of AlexNet in Functional API mode
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, losses, optimizers, datasets, utils
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, BatchNormalization, Flatten, Dropout

#tf.keras.backend.clear_session()
 
(x, y), (x_test, y_test) = datasets.cifar10.load_data()
y = tf.squeeze(y, axis=-1)
y_test = tf.squeeze(y_test, axis=-1)

def preprocess(x, y):
    x = 2 * tf.cast(x, dtype = tf.float32)/255. -1
    y = tf.cast(y, dtype = tf.int32)
    return x, y

train_db = tf.data.Dataset.from_tensor_slices((x, y))
train_db = train_db.shuffle(1000).map(preprocess).batch(128)

test_db = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_db = test_db.map(preprocess).batch(128)

alex_net_inputs = Input(shape=[32, 32, 3])
x = Conv2D(filters = 96, kernel_size=[11,11], strides = 4, padding = [[0,0],[2,2], [2,2],[0,0]], activation='relu')(alex_net_inputs)
x = MaxPool2D(pool_size=[3,3], strides = 2, padding='valid')(x)

x = Conv2D(filters = 256, kernel_size = [5,5], strides = 1, padding = [[0,0],[2,2], [2,2],[0,0]], activation = 'relu')(x)
x = MaxPool2D(pool_size=[3,3], strides = 2, padding='valid')(x)

x = Conv2D(filters = 384, kernel_size = [3,3], strides = 1, padding = [[0,0],[1,1], [1,1],[0,0]], activation = 'relu')(x)
x = Conv2D(filters = 384, kernel_size = [3,3], strides = 1, padding = [[0,0],[1,1], [1,1],[0,0]], activation = 'relu')(x)
x = Conv2D(filters = 256, kernel_size = [3,3], strides = 1, padding = [[0,0],[1,1], [1,1],[0,0]], activation = 'relu')(x)

x = MaxPool2D(pool_size=[3,3], strides = 1, padding = 'same')(x)
x = BatchNormalization()(x)
x = Flatten()(x)

x = Dense(4096, activation='relu')(x)
x = Dropout(rate = 0.2)(x)
x = Dense(4096, activation='relu')(x)
x = Dropout(rate = 0.2)(x)
alex_net_outputs = Dense(10, activation=None)(x)



model = Model(inputs = alex_net_inputs, outputs = alex_net_outputs, name ='alexnet')
model.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              #optimizer=keras.optimizers.RMSprop(),
              optimizer=keras.optimizers.Adam(lr=1e-4),
              metrics=['accuracy'])

history = model.fit(train_db, 
                    batch_size=64,
                    epochs=100)

test_scores = model.evaluate(test_db, verbose=2)
print('Test loss:', test_scores[0])
print('Test accuracy:', test_scores[1])
#
#utils.plot_model(model_alexnet, 'test.png')
# Out:
# Epoch 1/100
# 391/391 [==============================] - 5s 14ms/step - loss: 1.5453 - accuracy: 0.4242
# Epoch 2/100
# 391/391 [==============================] - 5s 14ms/step - loss: 1.2431 - accuracy: 0.5503
# Epoch 3/100
# 391/391 [==============================] - 5s 13ms/step - loss: 1.1137 - accuracy: 0.6007
# Epoch 4/100
# 391/391 [==============================] - 5s 13ms/step - loss: 1.0153 - accuracy: 0.6364
# Epoch 5/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.9413 - accuracy: 0.6662
# Epoch 6/100
# 391/391 [==============================] - 6s 14ms/step - loss: 0.8696 - accuracy: 0.6943
# Epoch 7/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.8098 - accuracy: 0.7151
# Epoch 8/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.7455 - accuracy: 0.7368
# Epoch 9/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.6881 - accuracy: 0.7587
# Epoch 10/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.6371 - accuracy: 0.7756
# Epoch 11/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.5802 - accuracy: 0.7988
# Epoch 12/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.5265 - accuracy: 0.8169
# Epoch 13/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.4782 - accuracy: 0.8332
# Epoch 14/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.4335 - accuracy: 0.8488
# Epoch 15/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3964 - accuracy: 0.8625
# Epoch 16/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.3556 - accuracy: 0.8773
# Epoch 17/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3202 - accuracy: 0.8889
# Epoch 18/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.2936 - accuracy: 0.8983
# Epoch 19/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.2556 - accuracy: 0.9101
# Epoch 20/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.2484 - accuracy: 0.9133
# Epoch 21/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2216 - accuracy: 0.9229
# Epoch 22/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2024 - accuracy: 0.9296
# Epoch 23/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.1832 - accuracy: 0.9358
# Epoch 24/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1765 - accuracy: 0.9371
# Epoch 25/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1610 - accuracy: 0.9420
# Epoch 26/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1465 - accuracy: 0.9478
# Epoch 27/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.1400 - accuracy: 0.9506
# Epoch 28/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.1301 - accuracy: 0.9544
# Epoch 29/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.1247 - accuracy: 0.9563
# Epoch 30/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1206 - accuracy: 0.9582
# Epoch 31/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.1164 - accuracy: 0.9594
# Epoch 32/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1024 - accuracy: 0.9646
# Epoch 33/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.1042 - accuracy: 0.9630
# Epoch 34/100
# 391/391 [==============================] - 6s 15ms/step - loss: 0.0968 - accuracy: 0.9664
# Epoch 35/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0951 - accuracy: 0.9672
# Epoch 36/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0944 - accuracy: 0.9675
# Epoch 37/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0881 - accuracy: 0.9693
# Epoch 38/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0867 - accuracy: 0.9694
# Epoch 39/100
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0833 - accuracy: 0.9706
# Epoch 40/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0775 - accuracy: 0.9734
# Epoch 41/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0792 - accuracy: 0.9720
# Epoch 42/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0734 - accuracy: 0.9741
# Epoch 43/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0758 - accuracy: 0.9733
# Epoch 44/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0716 - accuracy: 0.9747
# Epoch 45/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0633 - accuracy: 0.9774
# Epoch 46/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0716 - accuracy: 0.9750
# Epoch 47/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0706 - accuracy: 0.9751
# Epoch 48/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0630 - accuracy: 0.9780
# Epoch 49/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0615 - accuracy: 0.9785
# Epoch 50/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0636 - accuracy: 0.9776
# Epoch 51/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0591 - accuracy: 0.9795
# Epoch 52/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0609 - accuracy: 0.9779
# Epoch 53/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0569 - accuracy: 0.9804
# Epoch 54/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0577 - accuracy: 0.9795
# Epoch 55/100
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0572 - accuracy: 0.9800
# Epoch 56/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0523 - accuracy: 0.9822
# Epoch 57/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0510 - accuracy: 0.9823
# Epoch 58/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0568 - accuracy: 0.9802
# Epoch 59/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0513 - accuracy: 0.9824
# Epoch 60/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0526 - accuracy: 0.9824
# Epoch 61/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0497 - accuracy: 0.9831
# Epoch 62/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0500 - accuracy: 0.9831
# Epoch 63/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0457 - accuracy: 0.9839
# Epoch 64/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0475 - accuracy: 0.9838
# Epoch 65/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0484 - accuracy: 0.9827
# Epoch 66/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0487 - accuracy: 0.9828
# Epoch 67/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0447 - accuracy: 0.9846
# Epoch 68/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0413 - accuracy: 0.9859
# Epoch 69/100
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0474 - accuracy: 0.9840
# Epoch 70/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0434 - accuracy: 0.9846
# Epoch 71/100
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0452 - accuracy: 0.9848
# Epoch 72/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0388 - accuracy: 0.9865
# Epoch 73/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0442 - accuracy: 0.9849
# Epoch 74/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0422 - accuracy: 0.9852
# Epoch 75/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0447 - accuracy: 0.9848
# Epoch 76/100
# 391/391 [==============================] - 6s 15ms/step - loss: 0.0389 - accuracy: 0.9866
# Epoch 77/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0399 - accuracy: 0.9860
# Epoch 78/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0377 - accuracy: 0.9864
# Epoch 79/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0392 - accuracy: 0.9865
# Epoch 80/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0359 - accuracy: 0.9877
# Epoch 81/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0411 - accuracy: 0.9861
# Epoch 82/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0356 - accuracy: 0.9873
# Epoch 83/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0364 - accuracy: 0.9880
# Epoch 84/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0362 - accuracy: 0.9878
# Epoch 85/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0386 - accuracy: 0.9869
# Epoch 86/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0355 - accuracy: 0.9880
# Epoch 87/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0383 - accuracy: 0.9873
# Epoch 88/100
# 391/391 [==============================] - 6s 15ms/step - loss: 0.0342 - accuracy: 0.9878
# Epoch 89/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0344 - accuracy: 0.9884
# Epoch 90/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0321 - accuracy: 0.9888
# Epoch 91/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0306 - accuracy: 0.9896
# Epoch 92/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0318 - accuracy: 0.9887
# Epoch 93/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0353 - accuracy: 0.9880
# Epoch 94/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0359 - accuracy: 0.9878
# Epoch 95/100
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0279 - accuracy: 0.9907
# Epoch 96/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0299 - accuracy: 0.9895
# Epoch 97/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0340 - accuracy: 0.9885
# Epoch 98/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0296 - accuracy: 0.9898
# Epoch 99/100
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0344 - accuracy: 0.9878
# Epoch 100/100
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0337 - accuracy: 0.9879
# 79/79 - 1s - loss: 2.8738 - accuracy: 0.6417
# Test loss: 2.8737905025482178
# Test accuracy: 0.641700029373169

# %%
# Implementation of VGG16 in Functional API mode
from numpy import random
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, BatchNormalization, Flatten, Dropout
from tensorflow.keras import datasets, optimizers, losses, utils, Model, Input

(x, y), (x_test, y_test) = datasets.cifar10.load_data()
y = tf.squeeze(y, axis = -1)
y_test = tf.squeeze(y_test, axis = -1)

x = 2 * x.reshape(x.shape[0],32,32,3).astype('float32') / 255 - 1
#random.shuffle(x)
x_test = 2* x_test.reshape(x_test.shape[0],32,32,3).astype('float32')/ 255 -1

train_db = tf.data.Dataset.from_tensor_slices((x,y))
train_db = train_db.shuffle(1000).batch(128)
test_db = tf.data.Dataset.from_tensor_slices((x_test,y_test))
test_db = test_db.batch(128)

vgg16_inputs = Input(shape=[32,32,3])
x = Conv2D(filters = 64, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(vgg16_inputs)
x = Conv2D(filters = 64, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = MaxPool2D(pool_size=[2,2], strides=2, padding='valid')(x)

x = Conv2D(filters = 128, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = Conv2D(filters = 128, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = MaxPool2D(pool_size=[2,2], strides=2, padding='valid')(x)

x = Conv2D(filters = 256, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = Conv2D(filters = 256, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = Conv2D(filters = 256, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = MaxPool2D(pool_size=[2,2], strides=2, padding='valid')(x)

x = Conv2D(filters = 512, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = Conv2D(filters = 512, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = Conv2D(filters = 512, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = MaxPool2D(pool_size=[2,2], strides=2, padding='valid')(x)

x = Conv2D(filters = 512, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = Conv2D(filters = 512, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = Conv2D(filters = 512, kernel_size=[3,3], padding='same',strides = 1, activation=tf.nn.relu)(x)
x = MaxPool2D(pool_size=[2,2], strides=2, padding='valid')(x)

x = Flatten()(x)
x = Dense(4096, activation='relu')(x)
x = Dropout(rate=0.5)(x)
x = Dense(4096, activation='relu')(x)
x = Dropout(rate=0.5)(x)

vgg16_outputs = Dense(10, activation=None)(x)

model_vgg16 = Model(vgg16_inputs, vgg16_outputs, name = 'VGG16')
model_vgg16.summary()

# CategoricalCrossentropy for one-hot encoded y, e.g. [0,1,0]
# SparseCategoricalCrossentropy for integer labels, e.g. [2, 3]
model_vgg16.compile(optimizer = optimizers.Adam(lr=1e-4), 
              loss = losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics = ['accuracy'])

training_log = model_vgg16.fit(train_db, batch_size = 128, epochs = 100)

testing_results = model_vgg16.evaluate(test_db, verbose = 2)
print('Test loss: ', testing_results[0])
print('Test Accuracy: ', testing_results[1])
# Out:
# Model: "VGG16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_105 (Conv2D)          (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_106 (Conv2D)          (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_107 (Conv2D)          (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_108 (Conv2D)          (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_109 (Conv2D)          (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_110 (Conv2D)          (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_111 (Conv2D)          (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_112 (Conv2D)          (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_113 (Conv2D)          (None, 4, 4, 512)         2359808
# _________________________________________________________________
# conv2d_114 (Conv2D)          (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_115 (Conv2D)          (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 2, 2, 512)         2359808
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 4096)              2101248
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 4096)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 4096)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                40970
# =================================================================
# Total params: 33,638,218
# Trainable params: 33,638,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 391/391 [==============================] - 12s 31ms/step - loss: 1.8952 - accuracy: 0.2539
# Epoch 2/100
# 391/391 [==============================] - 12s 30ms/step - loss: 1.4897 - accuracy: 0.4296
# Epoch 3/100
# 391/391 [==============================] - 12s 30ms/step - loss: 1.2064 - accuracy: 0.5614
# Epoch 4/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.9827 - accuracy: 0.6517
# Epoch 5/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.8147 - accuracy: 0.7144
# Epoch 6/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.6748 - accuracy: 0.7629
# Epoch 7/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.5466 - accuracy: 0.8093
# Epoch 8/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.4415 - accuracy: 0.8488
# Epoch 9/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.3500 - accuracy: 0.8801
# Epoch 10/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.2765 - accuracy: 0.9065
# Epoch 11/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.2290 - accuracy: 0.9214
# Epoch 12/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.1902 - accuracy: 0.9361
# Epoch 13/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.1618 - accuracy: 0.9460
# Epoch 14/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.1356 - accuracy: 0.9548
# Epoch 15/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.1189 - accuracy: 0.9599
# Epoch 16/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.1095 - accuracy: 0.9635
# Epoch 17/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0914 - accuracy: 0.9699
# Epoch 18/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0887 - accuracy: 0.9712
# Epoch 19/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0755 - accuracy: 0.9745
# Epoch 20/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0742 - accuracy: 0.9756
# Epoch 21/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0696 - accuracy: 0.9767
# Epoch 22/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0648 - accuracy: 0.9789
# Epoch 23/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0653 - accuracy: 0.9793
# Epoch 24/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0601 - accuracy: 0.9801
# Epoch 25/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0578 - accuracy: 0.9819
# Epoch 26/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0504 - accuracy: 0.9840
# Epoch 27/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0575 - accuracy: 0.9816
# Epoch 28/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0512 - accuracy: 0.9840
# Epoch 29/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0490 - accuracy: 0.9843
# Epoch 30/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0459 - accuracy: 0.9849
# Epoch 31/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0483 - accuracy: 0.9849
# Epoch 32/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0474 - accuracy: 0.9852
# Epoch 33/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0442 - accuracy: 0.9863
# Epoch 34/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0384 - accuracy: 0.9877
# Epoch 35/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0427 - accuracy: 0.9865
# Epoch 36/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0402 - accuracy: 0.9875
# Epoch 37/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0393 - accuracy: 0.9876
# Epoch 38/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0372 - accuracy: 0.9880
# Epoch 39/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0400 - accuracy: 0.9869
# Epoch 40/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0382 - accuracy: 0.9882
# Epoch 41/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0367 - accuracy: 0.9887
# Epoch 42/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0317 - accuracy: 0.9896
# Epoch 43/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0335 - accuracy: 0.9891
# Epoch 44/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0333 - accuracy: 0.9894
# Epoch 45/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0338 - accuracy: 0.9896
# Epoch 46/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0315 - accuracy: 0.9904
# Epoch 47/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0283 - accuracy: 0.9911
# Epoch 48/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0329 - accuracy: 0.9902
# Epoch 49/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0291 - accuracy: 0.9905
# Epoch 50/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0273 - accuracy: 0.9917
# Epoch 51/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0285 - accuracy: 0.9911
# Epoch 52/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0244 - accuracy: 0.9926
# Epoch 53/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0295 - accuracy: 0.9906
# Epoch 54/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0255 - accuracy: 0.9921
# Epoch 55/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0253 - accuracy: 0.9924
# Epoch 56/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0275 - accuracy: 0.9915
# Epoch 57/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0259 - accuracy: 0.9921
# Epoch 58/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0299 - accuracy: 0.9910
# Epoch 59/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0189 - accuracy: 0.9941
# Epoch 60/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0224 - accuracy: 0.9930
# Epoch 61/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0222 - accuracy: 0.9933
# Epoch 62/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0214 - accuracy: 0.9936
# Epoch 63/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0208 - accuracy: 0.9939
# Epoch 64/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0239 - accuracy: 0.9929
# Epoch 65/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0265 - accuracy: 0.9921
# Epoch 66/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0196 - accuracy: 0.9941
# Epoch 67/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0207 - accuracy: 0.9934
# Epoch 68/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0273 - accuracy: 0.9919
# Epoch 69/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0193 - accuracy: 0.9938
# Epoch 70/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0182 - accuracy: 0.9943
# Epoch 71/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0263 - accuracy: 0.9919
# Epoch 72/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0165 - accuracy: 0.9950
# Epoch 73/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0190 - accuracy: 0.9942
# Epoch 74/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0182 - accuracy: 0.9943
# Epoch 75/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0206 - accuracy: 0.9940
# Epoch 76/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0198 - accuracy: 0.9938
# Epoch 77/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0173 - accuracy: 0.9949
# Epoch 78/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0152 - accuracy: 0.9953
# Epoch 79/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0202 - accuracy: 0.9937
# Epoch 80/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0222 - accuracy: 0.9932
# Epoch 81/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0188 - accuracy: 0.9941
# Epoch 82/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0165 - accuracy: 0.9951
# Epoch 83/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0171 - accuracy: 0.9951
# Epoch 84/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0153 - accuracy: 0.9955
# Epoch 85/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0188 - accuracy: 0.9944
# Epoch 86/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0124 - accuracy: 0.9961
# Epoch 87/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0165 - accuracy: 0.9949
# Epoch 88/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0159 - accuracy: 0.9950
# Epoch 89/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0198 - accuracy: 0.9943
# Epoch 90/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0178 - accuracy: 0.9949
# Epoch 91/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0132 - accuracy: 0.9960
# Epoch 92/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0167 - accuracy: 0.9944
# Epoch 93/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0122 - accuracy: 0.9964
# Epoch 94/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0171 - accuracy: 0.9949
# Epoch 95/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0154 - accuracy: 0.9958
# Epoch 96/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0147 - accuracy: 0.9956
# Epoch 97/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0170 - accuracy: 0.9949
# Epoch 98/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0123 - accuracy: 0.9964
# Epoch 99/100
# 391/391 [==============================] - 12s 30ms/step - loss: 0.0136 - accuracy: 0.9958
# Epoch 100/100
# 391/391 [==============================] - 12s 31ms/step - loss: 0.0146 - accuracy: 0.9955
# WARNING:tensorflow:Model was constructed with shape (None, 32, 32, 3) for input Tensor("input_10:0", shape=(None, 32, 32, 3), dtype=float32), but it was called on an input with incompatible shape (32, 32, 3).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ddbaf5404647> in <module>
#      59 training_log = model_vgg16.fit(train_db, batch_size = 128, epochs = 100)
#      60
# ---> 61 testing_results = model_vgg16.evaluate(test_db, verbose = 2)
#      62 print('Test loss: ', testing_results[0])
#      63 print('Test Accuracy: ', testing_results[1])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      63   def _method_wrapper(self, *args, **kwargs):
#      64     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 65       return method(self, *args, **kwargs)
#      66
#      67     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1011             with trace.Trace('TraceContext', graph_type='test', step_num=step):
#    1012               callbacks.on_test_batch_begin(step)
# -> 1013               tmp_logs = test_function(iterator)
#    1014               # Catch OutOfRangeError for Datasets of unknown size.
#    1015               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     577         xla_context.Exit()
#     578     else:
# --> 579       result = self._call(*args, **kwds)
#     580
#     581     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     624       # This is the first call of __call__, so we have to initialize.
#     625       initializers = []
# --> 626       self._initialize(args, kwds, add_initializers_to=initializers)
#     627     finally:
#     628       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     504     self._concrete_stateful_fn = (
#     505         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 506             *args, **kwds))
#     507
#     508     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2444       args, kwargs = None, None
#    2445     with self._lock:
# -> 2446       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2447     return graph_function
#    2448
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2775
#    2776       self._function_cache.missed.add(call_context_key)
# -> 2777       graph_function = self._create_graph_function(args, kwargs)
#    2778       self._function_cache.primary[cache_key] = graph_function
#    2779       return graph_function, args, kwargs
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2665             arg_names=arg_names,
#    2666             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2667             capture_by_value=self._capture_by_value),
#    2668         self._function_attributes,
#    2669         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     979         _, original_func = tf_decorator.unwrap(python_func)
#     980
# --> 981       func_outputs = python_func(*func_args, **func_kwargs)
#     982
#     983       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     439         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     440         # the function a weak reference to itself to avoid a reference cycle.
# --> 441         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     442     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     443
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     966           except Exception as e:  # pylint:disable=broad-except
#     967             if hasattr(e, "ag_error_metadata"):
# --> 968               raise e.ag_error_metadata.to_exception(e)
#     969             else:
#     970               raise
#
# ValueError: in user code:
#
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:876 test_function  *
#         outputs = self.distribute_strategy.run(
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py:951 run  **
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py:2290 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py:2649 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:844 test_step  **
#         y_pred = self(x, training=False)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py:926 __call__
#         outputs = call_fn(cast_inputs, *args, **kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py:714 call
#         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py:883 _run_internal_graph
#         output_tensors = layer(computed_tensors, **kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py:885 __call__
#         self.name)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/input_spec.py:180 assert_input_compatibility
#         str(x.shape.as_list()))
#
#     ValueError: Input 0 of layer conv2d_105 is incompatible with the layer: expected ndim=4, found ndim=3. Full shape received: [32, 32, 3]
